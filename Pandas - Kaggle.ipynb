# %% [markdown]
# https://www.kaggle.com/rudymizrahi/break-into-data-science-01-pandas-tutorial

# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# '/home/jovyan/binder'

# %%
data = pd.read_csv('/home/jovyan/acs2015_county_data.csv')

# %%
data.head(5)
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4      ...        0.5          1.3         1.8         26.5     23986
# 1     0.6      ...        1.0          1.4         3.9         26.4     85953
# 2     0.2      ...        1.8          1.5         1.6         24.1      8597
# 3     0.4      ...        0.6          1.5         0.7         28.8      8294
# 4     0.3      ...        0.9          0.4         2.3         34.9     22189
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 37 columns):
# CensusId           3220 non-null int64
# State              3220 non-null object
# County             3220 non-null object
# TotalPop           3220 non-null int64
# Men                3220 non-null int64
# Women              3220 non-null int64
# Hispanic           3220 non-null float64
# White              3220 non-null float64
# Black              3220 non-null float64
# Native             3220 non-null float64
# Asian              3220 non-null float64
# Pacific            3220 non-null float64
# Citizen            3220 non-null int64
# Income             3219 non-null float64
# IncomeErr          3219 non-null float64
# IncomePerCap       3220 non-null int64
# IncomePerCapErr    3220 non-null int64
# Poverty            3220 non-null float64
# ChildPoverty       3219 non-null float64
# Professional       3220 non-null float64
# Service            3220 non-null float64
# ...

# %%
data.shape
# Out:
# (3220, 37)

# %%
data = data.dropna(axis=0, how='any')
data.shape
# Out:
# (3218, 37)

# %%
data['M/W_ratio'] = data['Men']/data['Women']
data.head(5)
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native    ...      OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4    ...              1.3         1.8         26.5     23986
# 1     0.6    ...              1.4         3.9         26.4     85953
# 2     0.2    ...              1.5         1.6         24.1      8597
# 3     0.4    ...              1.5         0.7         28.8      8294
# 4     0.3    ...              0.4         2.3         34.9     22189
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment  M/W_ratio
# ...

# %%
data = data.drop(['CensusId'], axis=1)
data = data.groupby('State').sum()
data.head(5)
# Out:
#             TotalPop       Men     Women  Hispanic   White   Black  Native  \
# State
# Alabama      4830620   2341093   2489527     217.9  4390.7  1907.6    40.0
# Alaska        733375    384160    349215     133.5  1430.9    41.1   891.8
# Arizona      6641928   3299088   3342840     456.5   773.2    26.5   197.7
# Arkansas     2958208   1451913   1506295     370.2  5711.6  1205.2    36.0
# California  38421464  19087135  19334329    1712.1  3222.3   173.3    91.6
#
#             Asian  Pacific   Citizen    ...      OtherTransp  WorkAtHome  \
# State                                   ...
# Alabama      43.2      1.7   3620994    ...             76.0       159.9
# Alaska      172.6     18.6    523946    ...            282.9       184.4
# Arizona      18.7      1.8   4526594    ...             36.3        77.6
# Arkansas     51.0      5.1   2164083    ...             99.5       241.2
# California  400.1     19.9  24280349    ...            156.2       373.3
#
# ...

# %%
data.memory_usage(deep=True)
# Out:
# Index              3417
# TotalPop            416
# Men                 416
# Women               416
# Hispanic            416
# White               416
# Black               416
# Native              416
# Asian               416
# Pacific             416
# Citizen             416
# Income              416
# IncomeErr           416
# IncomePerCap        416
# IncomePerCapErr     416
# Poverty             416
# ChildPoverty        416
# Professional        416
# Service             416
# Office              416
# Construction        416
# Production          416
# Drive               416
# Carpool             416
# Transit             416
# Walk                416
# OtherTransp         416
# WorkAtHome          416
# MeanCommute         416
# Employed            416
# PrivateWork         416
# PublicWork          416
# SelfEmployed        416
# FamilyWork          416
# Unemployment        416
# M/W_ratio           416
# dtype: int64

# %%
data.dtypes
# Out:
# TotalPop             int64
# Men                  int64
# Women                int64
# Hispanic           float64
# White              float64
# Black              float64
# Native             float64
# Asian              float64
# Pacific            float64
# Citizen              int64
# Income             float64
# IncomeErr          float64
# IncomePerCap         int64
# IncomePerCapErr      int64
# Poverty            float64
# ChildPoverty       float64
# Professional       float64
# Service            float64
# Office             float64
# Construction       float64
# Production         float64
# Drive              float64
# Carpool            float64
# Transit            float64
# Walk               float64
# OtherTransp        float64
# WorkAtHome         float64
# MeanCommute        float64
# Employed             int64
# PrivateWork        float64
# PublicWork         float64
# SelfEmployed       float64
# FamilyWork         float64
# Unemployment       float64
# ...
